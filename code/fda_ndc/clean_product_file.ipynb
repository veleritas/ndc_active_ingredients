# %% [markdown]
# # Extract relevant information from the FDA product file
#
# 2019-05-07

# %%
import pandas as pd

# %% [markdown]
# # Read product info

# %%
product = pd.read_csv("../../data/fda_ndc/product.txt", sep='\t', encoding="latin")

# %%
product.shape
# Out:
# (129085, 20)

# %%
product.head()
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-0800_4bb5d1cb-0fa7-48c7-9f6d-8d45f9b91649  0002-0800
# 1  0002-1200_957ee1b5-dfa7-4e3f-96e1-6bed1ffc0abe  0002-1200
# 2  0002-1407_14757f9d-f641-4836-acf3-229265588d1d  0002-1407
# 3  0002-1433_4468578a-47d2-488e-9fd4-a8322070392f  0002-1433
# 4  0002-1434_4468578a-47d2-488e-9fd4-a8322070392f  0002-1434
#
#            PRODUCTTYPENAME      PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0           HUMAN OTC DRUG      Sterile Diluent                   NaN
# 1  HUMAN PRESCRIPTION DRUG               Amyvid                   NaN
# 2  HUMAN PRESCRIPTION DRUG  Quinidine Gluconate                   NaN
# 3  HUMAN PRESCRIPTION DRUG            Trulicity                   NaN
# 4  HUMAN PRESCRIPTION DRUG            Trulicity                   NaN
#
#     NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0              diluent  INJECTION, SOLUTION  SUBCUTANEOUS          19870710.0
# 1     Florbetapir F 18  INJECTION, SOLUTION   INTRAVENOUS          20120601.0
# 2  Quinidine Gluconate             SOLUTION   INTRAVENOUS          19500712.0
# 3          Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS          20140918.0
# 4          Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS          20140918.0
#
#    ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0               NaN                   NDA         NDA018781
# 1               NaN                   NDA         NDA202008
# 2               NaN                   NDA         NDA007529
# 3               NaN                   BLA         BLA125469
# 4               NaN                   BLA         BLA125469
#
#              LABELERNAME        SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Eli Lilly and Company                WATER                         1
# 1  Eli Lilly and Company     FLORBETAPIR F-18                        51
# 2  Eli Lilly and Company  QUINIDINE GLUCONATE                        80
# 3  Eli Lilly and Company          DULAGLUTIDE                       .75
# 4  Eli Lilly and Company          DULAGLUTIDE                       1.5
#
#   ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0              mL/mL                                                NaN
# 1             mCi/mL  Radioactive Diagnostic Agent [EPC],Positron Em...
# 2              mg/mL  Antiarrhythmic [EPC],Cytochrome P450 2D6 Inhib...
# 3            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 4            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
#
#   DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 0         NaN                N                        20191231.0
# 1         NaN                N                        20191231.0
# 2         NaN                N                        20191231.0
# 3         NaN                N                        20201231.0
# 4         NaN                N                        20201231.0

# %% [markdown]
# ### Look at missing data

# %%
(product
    .isnull()
    .sum()
    .to_frame("num_null")
    .assign(pct_null = lambda df: df["num_null"].divide(len(product)).multiply(100))
)
# Out:
#                                   num_null   pct_null
# PRODUCTID                                0   0.000000
# PRODUCTNDC                               0   0.000000
# PRODUCTTYPENAME                          0   0.000000
# PROPRIETARYNAME                          4   0.003099
# PROPRIETARYNAMESUFFIX               111674  86.511988
# NONPROPRIETARYNAME                       7   0.005423
# DOSAGEFORMNAME                           0   0.000000
# ROUTENAME                             2277   1.763954
# STARTMARKETINGDATE                       5   0.003873
# ENDMARKETINGDATE                    125157  96.957044
# MARKETINGCATEGORYNAME                    0   0.000000
# APPLICATIONNUMBER                    19611  15.192315
# LABELERNAME                              0   0.000000
# SUBSTANCENAME                         2760   2.138126
# ACTIVE_NUMERATOR_STRENGTH             2761   2.138901
# ACTIVE_INGRED_UNIT                    2760   2.138126
# PHARM_CLASSES                        73524  56.957818
# DEASCHEDULE                         124143  96.171515
# NDC_EXCLUDE_FLAG                         0   0.000000
# LISTING_RECORD_CERTIFIED_THROUGH      3930   3.044506

# %% [markdown]
# For our purposes we can remove information about marketing dates.

# %% [markdown]
# #### Product type

# %%
product["PRODUCTTYPENAME"].value_counts()
# Out:
# HUMAN OTC DRUG                 67447
# HUMAN PRESCRIPTION DRUG        58394
# NON-STANDARDIZED ALLERGENIC     2640
# PLASMA DERIVATIVE                325
# STANDARDIZED ALLERGENIC          149
# VACCINE                          123
# CELLULAR THERAPY                   7
# Name: PRODUCTTYPENAME, dtype: int64

# %% [markdown]
# #### Exclude flag

# %%
product["NDC_EXCLUDE_FLAG"].value_counts()
# Out:
# N    97474
# E    31611
# Name: NDC_EXCLUDE_FLAG, dtype: int64

# %% [markdown]
# #### DEA schedules

# %%
product[product["DEASCHEDULE"].notnull()].head()
# Out:
#                                           PRODUCTID PRODUCTNDC  \
# 135  0004-0058_5426a9bb-5c51-41b3-a957-ce7242d77bb9  0004-0058
# 136  0004-0068_5426a9bb-5c51-41b3-a957-ce7242d77bb9  0004-0068
# 137  0004-0098_5426a9bb-5c51-41b3-a957-ce7242d77bb9  0004-0098
# 167  0006-0005_bb901df0-9843-4179-8d00-45d144ab7c82  0006-0005
# 171  0006-0033_bb901df0-9843-4179-8d00-45d144ab7c82  0006-0033
#
#              PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 135  HUMAN PRESCRIPTION DRUG        Klonopin                   NaN
# 136  HUMAN PRESCRIPTION DRUG        Klonopin                   NaN
# 137  HUMAN PRESCRIPTION DRUG        Klonopin                   NaN
# 167  HUMAN PRESCRIPTION DRUG        BELSOMRA                   NaN
# 171  HUMAN PRESCRIPTION DRUG        BELSOMRA                   NaN
#
#     NONPROPRIETARYNAME       DOSAGEFORMNAME ROUTENAME  STARTMARKETINGDATE  \
# 135         Clonazepam               TABLET      ORAL          19750602.0
# 136         Clonazepam               TABLET      ORAL          19750602.0
# 137         Clonazepam               TABLET      ORAL          19750602.0
# 167         suvorexant  TABLET, FILM COATED      ORAL          20140829.0
# 171         suvorexant  TABLET, FILM COATED      ORAL          20140829.0
#
#      ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 135               NaN                   NDA         NDA017533
# 136               NaN                   NDA         NDA017533
# 137               NaN                   NDA         NDA017533
# 167               NaN                   NDA         NDA204569
# 171               NaN                   NDA         NDA204569
#
#                    LABELERNAME SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 135            Genentech, Inc.    CLONAZEPAM                         1
# 136            Genentech, Inc.    CLONAZEPAM                        .5
# 137            Genentech, Inc.    CLONAZEPAM                         2
# 167  Merck Sharp & Dohme Corp.    SUVOREXANT                         5
# 171  Merck Sharp & Dohme Corp.    SUVOREXANT                        10
#
#     ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 135               mg/1          Benzodiazepine [EPC],Benzodiazepines [CS]
# 136               mg/1          Benzodiazepine [EPC],Benzodiazepines [CS]
# 137               mg/1          Benzodiazepine [EPC],Benzodiazepines [CS]
# 167               mg/1  Orexin Receptor Antagonist [EPC],Orexin Recept...
# 171               mg/1  Orexin Receptor Antagonist [EPC],Orexin Recept...
#
#     DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 135         CIV                N                        20191231.0
# 136         CIV                N                        20191231.0
# 137         CIV                N                        20191231.0
# 167         CIV                N                        20191231.0
# 171         CIV                N                        20191231.0

# %%
product[product["DEASCHEDULE"].notnull()]["DEASCHEDULE"].value_counts()
# Out:
# CIV     2100
# CII     2072
# CIII     569
# CV       201
# Name: DEASCHEDULE, dtype: int64

# %% [markdown]
# This might be useful as an indicator for how "dangerous" a drug is to the patient, since they can cause dependency.

# %% [markdown]
# #### Suffix

# %%
product[product["PROPRIETARYNAMESUFFIX"].notnull()].head()
# Out:
#                                          PRODUCTID PRODUCTNDC  \
# 8   0002-3004_f1404e9d-0c95-44e4-9eb0-7a2836a67bd8  0002-3004
# 32  0002-4453_cd0ef401-5aed-4406-a26a-ab4c377409fe  0002-4453
# 33  0002-4454_cd0ef401-5aed-4406-a26a-ab4c377409fe  0002-4454
# 34  0002-4455_cd0ef401-5aed-4406-a26a-ab4c377409fe  0002-4455
# 35  0002-4456_cd0ef401-5aed-4406-a26a-ab4c377409fe  0002-4456
#
#             PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 8   HUMAN PRESCRIPTION DRUG          Prozac                Weekly
# 32  HUMAN PRESCRIPTION DRUG         ZYPREXA                Zydis
# 33  HUMAN PRESCRIPTION DRUG         ZYPREXA                Zydis
# 34  HUMAN PRESCRIPTION DRUG         ZYPREXA                Zydis
# 35  HUMAN PRESCRIPTION DRUG         ZYPREXA                Zydis
#
#           NONPROPRIETARYNAME                 DOSAGEFORMNAME ROUTENAME  \
# 8   Fluoxetine hydrochloride       CAPSULE, DELAYED RELEASE      ORAL
# 32                Olanzapine  TABLET, ORALLY DISINTEGRATING      ORAL
# 33                Olanzapine  TABLET, ORALLY DISINTEGRATING      ORAL
# 34                Olanzapine  TABLET, ORALLY DISINTEGRATING      ORAL
# 35                Olanzapine  TABLET, ORALLY DISINTEGRATING      ORAL
#
#     STARTMARKETINGDATE  ENDMARKETINGDATE MARKETINGCATEGORYNAME  \
# 8           20010316.0               NaN                   NDA
# 32          20000601.0               NaN                   NDA
# 33          20000601.0               NaN                   NDA
# 34          20010901.0               NaN                   NDA
# 35          20010901.0               NaN                   NDA
#
#    APPLICATIONNUMBER            LABELERNAME             SUBSTANCENAME  \
# 8          NDA021235  Eli Lilly and Company  FLUOXETINE HYDROCHLORIDE
# 32         NDA021086  Eli Lilly and Company                OLANZAPINE
# 33         NDA021086  Eli Lilly and Company                OLANZAPINE
# 34         NDA021086  Eli Lilly and Company                OLANZAPINE
# 35         NDA021086  Eli Lilly and Company                OLANZAPINE
#
#    ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 8                         90               mg/1
# 32                         5               mg/1
# 33                        10               mg/1
# 34                        15               mg/1
# 35                        20               mg/1
#
#                                         PHARM_CLASSES DEASCHEDULE  \
# 8   Serotonin Reuptake Inhibitor [EPC],Serotonin U...         NaN
# 32                       Atypical Antipsychotic [EPC]         NaN
# 33                       Atypical Antipsychotic [EPC]         NaN
# 34                       Atypical Antipsychotic [EPC]         NaN
# 35                       Atypical Antipsychotic [EPC]         NaN
#
#    NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 8                 N                        20191231.0
# 32                N                        20191231.0
# 33                N                        20191231.0
# 34                N                        20191231.0
# 35                N                        20191231.0

# %% [markdown]
# Suffix is not very useful for now, only for naming the full name of the drug.

# %% [markdown]
# ### Simplify product table

# %%
gproduct = product.drop(
    ["PROPRIETARYNAMESUFFIX", "STARTMARKETINGDATE", "ENDMARKETINGDATE"], axis=1
)

# %%
gproduct.shape
# Out:
# (129085, 17)

# %%
gproduct.head()
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-0800_4bb5d1cb-0fa7-48c7-9f6d-8d45f9b91649  0002-0800
# 1  0002-1200_957ee1b5-dfa7-4e3f-96e1-6bed1ffc0abe  0002-1200
# 2  0002-1407_14757f9d-f641-4836-acf3-229265588d1d  0002-1407
# 3  0002-1433_4468578a-47d2-488e-9fd4-a8322070392f  0002-1433
# 4  0002-1434_4468578a-47d2-488e-9fd4-a8322070392f  0002-1434
#
#            PRODUCTTYPENAME      PROPRIETARYNAME   NONPROPRIETARYNAME  \
# 0           HUMAN OTC DRUG      Sterile Diluent              diluent
# 1  HUMAN PRESCRIPTION DRUG               Amyvid     Florbetapir F 18
# 2  HUMAN PRESCRIPTION DRUG  Quinidine Gluconate  Quinidine Gluconate
# 3  HUMAN PRESCRIPTION DRUG            Trulicity          Dulaglutide
# 4  HUMAN PRESCRIPTION DRUG            Trulicity          Dulaglutide
#
#         DOSAGEFORMNAME     ROUTENAME MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0  INJECTION, SOLUTION  SUBCUTANEOUS                   NDA         NDA018781
# 1  INJECTION, SOLUTION   INTRAVENOUS                   NDA         NDA202008
# 2             SOLUTION   INTRAVENOUS                   NDA         NDA007529
# 3  INJECTION, SOLUTION  SUBCUTANEOUS                   BLA         BLA125469
# 4  INJECTION, SOLUTION  SUBCUTANEOUS                   BLA         BLA125469
#
#              LABELERNAME        SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Eli Lilly and Company                WATER                         1
# 1  Eli Lilly and Company     FLORBETAPIR F-18                        51
# 2  Eli Lilly and Company  QUINIDINE GLUCONATE                        80
# 3  Eli Lilly and Company          DULAGLUTIDE                       .75
# 4  Eli Lilly and Company          DULAGLUTIDE                       1.5
#
#   ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0              mL/mL                                                NaN
# 1             mCi/mL  Radioactive Diagnostic Agent [EPC],Positron Em...
# 2              mg/mL  Antiarrhythmic [EPC],Cytochrome P450 2D6 Inhib...
# 3            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 4            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
#
#   DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 0         NaN                N                        20191231.0
# 1         NaN                N                        20191231.0
# 2         NaN                N                        20191231.0
# 3         NaN                N                        20201231.0
# 4         NaN                N                        20201231.0

# %%
gproduct.isnull().sum()
# Out:
# PRODUCTID                                0
# PRODUCTNDC                               0
# PRODUCTTYPENAME                          0
# PROPRIETARYNAME                          4
# NONPROPRIETARYNAME                       7
# DOSAGEFORMNAME                           0
# ROUTENAME                             2277
# MARKETINGCATEGORYNAME                    0
# APPLICATIONNUMBER                    19611
# LABELERNAME                              0
# SUBSTANCENAME                         2760
# ACTIVE_NUMERATOR_STRENGTH             2761
# ACTIVE_INGRED_UNIT                    2760
# PHARM_CLASSES                        73524
# DEASCHEDULE                         124143
# NDC_EXCLUDE_FLAG                         0
# LISTING_RECORD_CERTIFIED_THROUGH      3930
# dtype: int64

# %% [markdown]
# According to the documentation, it seems like non-proprietary name and substance name are the most useful for identifying the active ingredient.
#
# Documentation link: https://www.fda.gov/drugs/drug-approvals-and-databases/ndc-product-file-definitions

# %% [markdown]
# ## Save to file

# %%
gproduct.to_csv("../../pipeline/fda_ndc/simple_product.tsv", sep='\t', index=False)
